# %% [markdown]
# <a href="https://colab.research.google.com/github/WesterDrizzle/TTS/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:51
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5712, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 5712 (delta 39), reused 10 (delta 10), pack-reused 5651 (from 3)
# Receiving objects: 100% (5712/5712), 13.68 MiB | 18.39 MiB/s, done.
# Resolving deltas: 100% (3377/3377), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.9.9   |       h06a4308_0         127 KB
# ...

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://45e9ebdf0c4724819e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/inference_webui_fast.py "Auto"
# ---------------------------------------------TTS Config---------------------------------------------
# device              : cuda
# is_half             : True
# version             : v2Pro
# t2s_weights_path    : GPT_weights_v2Pro/yinyue-e50.ckpt
# vits_weights_path   : SoVITS_weights_v2Pro/yinyue_e25_s225.pth
# bert_base_path      : GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
# cnhuhbert_base_path : GPT_SoVITS/pretrained_models/chinese-hubert-base
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !zip -r yinyue_GPT_weights.zip GPT-SoVITS/GPT_weights_v2Pro/
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/ (stored 0%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e40.ckpt (deflated 8%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e20.ckpt (deflated 8%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e10.ckpt (deflated 8%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e45.ckpt (deflated 8%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e30.ckpt (deflated 8%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e50.ckpt (deflated 8%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e5.ckpt (deflated 8%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e35.ckpt (deflated 8%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e15.ckpt (deflated 8%)
#   adding: GPT-SoVITS/GPT_weights_v2Pro/yinyue-e25.ckpt (deflated 8%)

# %%
# !zip -r yinyue_SoVITS_weights_v2Pro.zip GPT-SoVITS/SoVITS_weights_v2Pro/
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#   adding: GPT-SoVITS/SoVITS_weights_v2Pro/ (stored 0%)
#   adding: GPT-SoVITS/SoVITS_weights_v2Pro/yinyue_e5_s45.pth (deflated 8%)
#   adding: GPT-SoVITS/SoVITS_weights_v2Pro/yinyue_e20_s180.pth (deflated 8%)
#   adding: GPT-SoVITS/SoVITS_weights_v2Pro/yinyue_e15_s135.pth (deflated 8%)
#   adding: GPT-SoVITS/SoVITS_weights_v2Pro/yinyue_e10_s90.pth (deflated 8%)
#   adding: GPT-SoVITS/SoVITS_weights_v2Pro/yinyue_e25_s225.pth (deflated 8%)

# %%
# !cp yinyue_GPT_weights_v2Pro.zip  /content/drive/MyDrive/yinyue_GPT_weights_v2Pro.zip
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !cp yinyue_SoVITS_weights_v2Pro.zip  /content/drive/MyDrive/yinyue_SoVITS_weights_v2Pro.zip
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
